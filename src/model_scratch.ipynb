# %%
import config as c
import torch
import torch.optim
import torch.nn as nn
import numpy as np
from iResNet import *
from model import Architecture
from torch.distributions import Normal, kl_divergence
import matplotlib.pyplot as plt
device = 'cpu'

# %%
x_c = torch.randn([16, 5, 3, 64, 64])
v_c = torch.randn([16, 5, 7])
x_q = torch.zeros([16, 3, 64, 64])
v_q = torch.randn([16, 7])

# %%
m = Architecture(device)

# %%
x_mu, x, _, _ = m(x_c, v_c, x_q, v_q)

# %%
x_mu.shape

# %%
idx = 0
plt.figure()
plt.imshow(x_mu[idx].permute(1,2,0).detach().cpu().numpy())

# %%
plt.figure()
plt.imshow(x_q[idx].permute(1,2,0).detach().cpu().numpy())

# %%
x_sa = m.gqn_sample(x_c, v_c, v_q)

# %%
plt.figure()
plt.imshow(x_sa[idx].permute(1,2,0).detach().cpu().numpy())
